# %% [markdown]
# #### Use pacman to package loading the rio

# %%
install.packages("pacman")
pacman::p_load(pacman, rio)
# Out:
# Warning message:
# "package 'pacman' is in use and will not be installed"

# %% [markdown]
# #### This is to import data from csv txt etc

# %%
rio_csv <- import("mbb.csv")
head(rio_csv)
# Out:
#   Month   Mozart Beethoven Bach
# 1 2004-01 12     8         15
# 2 2004-02 12     9         15
# 3 2004-03 12     9         14
# 4 2004-04 12     8         14
# 5 2004-05 11     9         13
# 6 2004-06  9     7         12

# %%
rio_text <- import("mbb.txt")
head(rio_text)
# Out:
#   Month   Mozart Beethoven Bach
# 1 2004-01 12     8         15
# 2 2004-02 12     9         15
# 3 2004-03 12     9         14
# 4 2004-04 12     8         14
# 5 2004-05 11     9         13
# 6 2004-06  9     7         12

# %%
rio_xlsx <- import("mbb.xlsx")
head(rio_xlsx)
# Out:
#   Month   Mozart Beethoven Bach
# 1 2004-01 12     8         15
# 2 2004-02 12     9         15
# 3 2004-03 12     9         14
# 4 2004-04 12     8         14
# 5 2004-05 11     9         13
# 6 2004-06  9     7         12

# %% [markdown]
# #### Use the data viewer to view the csv file.

# %%
?View
View(rio_csv)
# Out:
#     Month   Mozart Beethoven Bach
# 1   2004-01  12    8         15
# 2   2004-02  12    9         15
# 3   2004-03  12    9         14
# 4   2004-04  12    8         14
# 5   2004-05  11    9         13
# 6   2004-06   9    7         12
# 7   2004-07   7    5         11
# 8   2004-08   7    6         11
# 9   2004-09   9    7         12
# 10  2004-10  11    8         13
# 11  2004-11  11    8         14
# 12  2004-12  10    8         13
# 13  2005-01  11    8         13
# 14  2005-02  11    8         16
# 15  2005-03  10    8         13
# 16  2005-04  11    8         13
# 17  2005-05  11    8         12
# 18  2005-06   9    7         12
# 19  2005-07   7    5         11
# 20  2005-08   7    5         12
# 21  2005-09   9    6         11
# 22  2005-10  10    7         12
# 23  2005-11  11    7         12
# 24  2005-12  11    7         12
# 25  2006-01 100    7         13
# 26  2006-02  25    7         12
# 27  2006-03  19    7         14
# 28  2006-04  14    6         12
# ...

# %%
r_txt1 <- read.table("mbb.txt", header = TRUE)
# have missing value so cannot
# Out:
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# "number of items read is not a multiple of the number of columns"

# %%
r_txt2 <- read.table("mbb.txt", 
  header = TRUE, 
  sep = "\t")

r_txt2
# Out:
#     Month   Mozart Beethoven Bach
# 1   2004-01  12    8         15
# 2   2004-02  12    9         15
# 3   2004-03  12    9         14
# 4   2004-04  12    8         14
# 5   2004-05  11    9         13
# 6   2004-06   9    7         12
# 7   2004-07   7    5         11
# 8   2004-08   7    6         11
# 9   2004-09   9    7         12
# 10  2004-10  11    8         13
# 11  2004-11  11    8         14
# 12  2004-12  10    8         13
# 13  2005-01  11    8         13
# 14  2005-02  11    8         16
# 15  2005-03  10    8         13
# 16  2005-04  11    8         13
# 17  2005-05  11    8         12
# 18  2005-06   9    7         12
# 19  2005-07   7    5         11
# 20  2005-08   7    5         12
# 21  2005-09   9    6         11
# 22  2005-10  10    7         12
# 23  2005-11  11    7         12
# 24  2005-12  11    7         12
# 25  2006-01 100    7         13
# 26  2006-02  25    7         12
# 27  2006-03  19    7         14
# 28  2006-04  14    6         12
# ...

# %%
trends.csv <- read.csv("mbb.csv", header = TRUE)

# %%
rm(list = ls()) 

# Clear packages
p_unload(all)  # Remove all add-ons

# Clear console
cat("\014")  # ctrl+L

# Clear mind :)
# Out:
# The following packages have been unloaded:
# rio, pacman
